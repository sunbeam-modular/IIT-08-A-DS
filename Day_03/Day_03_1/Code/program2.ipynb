# %% [markdown]
# ## read the csv file and find correlation between columns/features/variables using df.corr()

# %% [markdown]
# ## import the required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## read the data
df=pd.read_csv("Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        33.000000      33.000000
# mean          5.921212   82760.303030
# std           3.342413   34014.620992
# min           1.100000   37731.000000
# 25%           3.200000   56957.000000
# 50%           5.100000   67938.000000
# 75%           8.700000  109431.000000
# max          13.000000  156000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 660.0 bytes

# %%
#  Correlation , to see whether columns are related
corr = df.corr()

# %%
corr
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.983642
# Salary                  0.983642  1.000000

# %%
corr.style.background_gradient(cmap='berlin')
# Out:
# <style type="text/css">
# #T_34acf_row0_col0, #T_34acf_row1_col1 {
#   background-color: #ffadad;
#   color: #000000;
# }
# #T_34acf_row0_col1, #T_34acf_row1_col0 {
#   background-color: #9eb0ff;
#   color: #000000;
# }
# </style>
# <table id="T_34acf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34acf_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_34acf_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34acf_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_34acf_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_34acf_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_34acf_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_34acf_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %%
corr.style.background_gradient(cmap='vanimo')
# Out:
# <style type="text/css">
# #T_72343_row0_col0, #T_72343_row1_col1 {
#   background-color: #befda5;
#   color: #000000;
# }
# #T_72343_row0_col1, #T_72343_row1_col0 {
#   background-color: #ffcdfd;
#   color: #000000;
# }
# </style>
# <table id="T_72343">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72343_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_72343_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72343_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_72343_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_72343_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_72343_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_72343_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %%
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style type="text/css">
# #T_666cb_row0_col0, #T_666cb_row1_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_666cb_row0_col1, #T_666cb_row1_col0 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_666cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_666cb_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_666cb_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_666cb_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_666cb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_666cb_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_666cb_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_666cb_row1_col0" class="data row1 col0" >0.983642</td>
# ...
